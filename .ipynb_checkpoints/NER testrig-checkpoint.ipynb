# %%
#spacy
import spacy
from spacy.pipeline import EntityRuler
from spacy.lang.en import English
from spacy.tokens import Doc

#gensimx
import gensim
from gensim import corpora

#Visualization
from spacy import displacy
import pyLDAvis.gensim_models
from wordcloud import WordCloud
import plotly.express as px
import matplotlib.pyplot as plt

#Data loading/ Data manipulation
import pandas as pd
import numpy as np
import jsonlines

#nltk
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
#nltk.download(['stopwords','wordnet'])

#warning
import warnings 
warnings.filterwarnings('ignore')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
extract = pd.read_csv('TestPostings.csv', encoding='ISO-8859-1')
df = pd.read_csv("Resume.csv")
df = df.reindex(np.random.permutation(df.index))
data = df.copy().iloc[
    0:18,
]
data.head()
# Out:
#             ID                                         Resume_str  \
# 2060  18436190           PUBLIC RELATIONS MANAGER         High...
# 2244  19437318           LEAD TELLER         Summary     Bank ...
# 1093  28139742           SALES ASSOCIATE       Summary      Cu...
# 999   20552814           SALES         Summary    Enthusiastic...
# 706   20748468           HEALTHCARE ADMINISTRATOR/OPERATIONAL ...
#
#                                             Resume_html          Category
# 2060  <div class="fontsize fontface vmargins hmargin...  PUBLIC-RELATIONS
# 2244  <div class="fontsize fontface vmargins hmargin...           BANKING
# 1093  <div class="fontsize fontface vmargins hmargin...             SALES
# 999   <div class="fontsize fontface vmargins hmargin...             SALES
# 706   <div class="fontsize fontface vmargins hmargin...        HEALTHCARE

# %%
nlp.pipe_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11088/3656461729.py in <module>
# ----> 1 nlp.pipe_names
#
# NameError: name 'nlp' is not defined

# %%
#TAKES VERY LONG TIME TO CLEAN DO NOT LOAD
def cleaner(data):
    clean = []
    for i in range(data.shape[0]):
        review = re.sub(
            '(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?"',
            " ",
            data["Resume_str"].iloc[i],
        )
        review = review.lower()
        review = review.split()
        """
        lm = WordNetLemmatizer()
        review = [
            lm.lemmatize(word)
            for word in review
            if not word in set(stopwords.words("english"))
        ]
        """
        review = " ".join(review)
        clean.append(review)
    return clean
clean = cleaner(data)

# %%
#CLEANED RESUME
data["Clean_Resume"] = clean
data["skills"] = data["Clean_Resume"].str.lower().apply(get_skills)
data["skills"] = data["skills"].apply(unique_skills)
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11088/3432689255.py in <module>
#       1 #CLEANED RESUME
#       2 data["Clean_Resume"] = clean
# ----> 3 data["skills"] = data["Clean_Resume"].str.lower().apply(get_skills)
#       4 data["skills"] = data["skills"].apply(unique_skills)
#       5 data.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_11088/2760909509.py in get_skills(text)
#       1 def get_skills(text):
# ...

# %%
extract.rename(columns={'Job Description':'Resume_str'},inplace=True)
extract
cleanJobsDesc = cleaner(extract)

# %%
extract["Clean_Resume"] = cleanJobsDesc
extract
# Out:
#                                                 Title  \
# 0                              Management Accountant
# 1                                   Business Analyst
# 2            Policy, Programmes and Research Officer
# 3                                           Animator
# 4    Graduate Technical Engineer (Civil / Construc...
# 5    School Immunisation Nurse â North Hertfords...
# 6    Freelance Private Chef - UK'S FASTEST GROWING...
# 7                              Management Consultant
# 8                  Trainee Solicitor - London (2023)
# 9                              Male Security Officer
# 10                                  Personal Trainer
# 11                                  Research Analyst
# 12                        Junior iMovie Video Editor
# 13   E-Commerce Executive Amazon Marketplace Speci...
# 14                                Clinical Scientist
# 15            E-Commerce Product Operations Assitant
# 16                                   Sales Associate
# ...

# %%
with open ("dataset.txt", 'w', encoding="utf-8") as f:
    for job in extract["Clean_Resume"]:
        f.write(job +"\n")
    for job in data["Clean_Resume"]:
        f.write(job +"\n")

# %%
# Out:
#                                                 Title  \
# 0                              Management Accountant
# 1                                   Business Analyst
# 2            Policy, Programmes and Research Officer
# 3                                           Animator
# 4    Graduate Technical Engineer (Civil / Construc...
# 5    School Immunisation Nurse â North Hertfords...
# 6    Freelance Private Chef - UK'S FASTEST GROWING...
# 7                              Management Consultant
# 8                  Trainee Solicitor - London (2023)
# 9                              Male Security Officer
# 10                                  Personal Trainer
# 11                                  Research Analyst
# 12                        Junior iMovie Video Editor
# 13   E-Commerce Executive Amazon Marketplace Speci...
# 14                                Clinical Scientist
# 15            E-Commerce Product Operations Assitant
# 16                                   Sales Associate
# ...

# %%
def get_skills(text):
    doc = nlp(text)
    myset = []
    subset = []
    for ent in doc.ents:
        if ent.label_ == "SKILL":
            subset.append(ent.text)
        if ent.label_ == "SOFT-SKILL":
            subset.append(ent.text)
    myset.append(subset)
    return subset

def get_soft_skills(text):
    doc = nlp(text)
    myset = []
    subset = []
    for ent in doc.ents:
        if ent.label_ == "SOFT-SKILL":
            subset.append(ent.text)
    myset.append(subset)
    
def unique_skills(x):
    return list(set(x))

# %%
import spacy
import json
import random

def load_data(file):
    data = []
    with open(file, 'r', encoding="latin1") as f:
        for line in f:
            line=json.loads(line)
            if "label" in line:
                line["entities"] = line.pop("label")
            else:
                line["entities"] = []
            tmp_ents = []
            for e in line["entities"]:
                if e[2] in ['SKILL', 'SOFT-SKILL']:
                    tmp_ents.append((e[0], e[1], e[2]))

                line["entities"] = tmp_ents
                data.append((line["data"], line["entities"]))
    return data

def save_data(file, data):
    with open (file, 'w', encoding="utf-8") as f:
        json.dump(data, f, indent =4)

# %%
from spacy.tokens import DocBin
def spacySave(training_data, train=True, test=False):
    nlp = spacy.blank("en")
    db = DocBin()
    print(len(training_data))
    for text, annotations in training_data:
        doc = nlp(text)
        ents = []
        for start, end, label in annotations:
            span = doc.char_span(start, end, label=label)
            ents.append(span)
        doc.ents = ents
        db.add(doc)
    if(train):
        db.to_disk("./train.spacy")
    if(test):
        db.to_disk("./test.spacy")

# %%
TRAIN_DATA = load_data("all.jsonl")
TEST_DATA = load_data("test.jsonl")
spacySave(TRAIN_DATA)
spacySave(TEST_DATA, train=False, test=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21916/2456190194.py in <module>
#       1 TRAIN_DATA = load_data("all.jsonl")
#       2 TEST_DATA = load_data("test.jsonl")
# ----> 3 spacySave(TRAIN_DATA)
#       4 spacySave(TEST_DATA, train=False, test=True)
#
# ~\AppData\Local\Temp/ipykernel_21916/578179812.py in spacySave(training_datal, train, test)
#       3     nlp = spacy.blank("en")
#       4     db = DocBin()
# ----> 5     print(len(training_data))
#       6     for text, annotations in training_data:
#       7         doc = nlp(text)
#
# NameError: name 'training_data' is not defined

# %%
from spacy.cli.train import train
train("./config.cfg", "./output", overrides={"paths.train": "./train.spacy", "paths.dev": "./train.spacy"})
# Out:
# ℹ Saving to output directory: output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.003
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10016/2343126801.py in <module>
#       1 from spacy.cli.train import train
# ----> 2 train("./config.cfg", "./output", overrides={"paths.train": "./train.spacy", "paths.dev": "./train.spacy"})
#
# ~\anaconda3\lib\site-packages\spacy\cli\train.py in train(config_path, output_path, use_gpu, overrides)
#      73     msg.good("Initialized pipeline")
# ...

# %%
def train_spacy(TRAIN_DATA, iterations):
    nlp = spacy.blank("en")
    #ruler = nlp.add_pipe("entity_ruler")
    #skill_pattern_path = "jz_skill_patterns.jsonl"
    #ruler.from_disk(skill_pattern_path)
    ner = nlp.add_pipe("ner", name="skills_ner")
    ner.add_label("SKILL")
    ner.add_label("SOFT-SKILL")
    other_pipes = [pipes for pipe in nlp.pipe_names if pipe !="skills_ner"]
    with nlp.disable_pipes(other_pipes):
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print(f"Starting iteration {(str(itn))}")
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                print(text)
                nlp.update([text],
                           [annotations], 
                           drop=0.2, 
                           sgd=optimizer, 
                           losses=losses
                )
            print(losses)
    return(nlp)
